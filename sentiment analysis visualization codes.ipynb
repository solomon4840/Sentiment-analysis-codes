# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 

plt.style.use('ggplot')
import nltk
df = pd.read_csv('Flipkart analyzed data.csv')
print (df.head())
# Out:
#    id    neg    neu    pos  compound  \
# 0   0  0.073  0.613  0.314    0.9579
# 1   1  0.000  0.256  0.744    0.4404
# 2   2  0.000  0.881  0.119    0.5789
# 3   3  0.000  0.432  0.568    0.8808
# 4   4  0.000  0.533  0.467    0.8360
#
#                                         Product_name  \
# 0  Lenovo Ideapad Gaming 3 Ryzen 5 Hexa Core 5600...
# 1  Lenovo Ideapad Gaming 3 Ryzen 5 Hexa Core 5600...
# 2  Lenovo Ideapad Gaming 3 Ryzen 5 Hexa Core 5600...
# 3  DELL Inspiron Athlon Dual Core 3050U - (4 GB/2...
# 4  DELL Inspiron Athlon Dual Core 3050U - (4 GB/2...
#
#                                               Review  Rating
# 0  Best under 60k Great performanceI got it for a...       5
# 1                                 Good perfomence...       5
# 2  Great performance but usually it has also that...       5
# 3           My wife is so happy and best product 👌🏻😘       5
# 4  Light weight laptop with new amazing features,...       5

# %%
print(df.columns)
# Out:
# Index(['id', 'neg', 'neu', 'pos', 'compound', 'Product_name', 'Review',
#        'Rating'],
#       dtype='object')

# %%
# Count the number of positive, negative, and neutral sentiments
pos_count = df['pos'].sum()
neg_count = df['neg'].sum()
neutral_count = df['neu'].sum()

# Create a summary of the sentiment counts
sentiment_counts = {
    'positive': pos_count,
    'negative': neg_count,
    'neutral': neutral_count
}

# Print the sentiment counts
print(sentiment_counts)
# Out:
# {'positive': np.float64(183.90200000000004), 'negative': np.float64(22.217000000000002), 'neutral': np.float64(293.87800000000004)}

# %%
# Count the number of positive, negative, and neutral sentiments as integers
pos_count = df['pos'].sum().astype(int)
neg_count = df['neg'].sum().astype(int)
neutral_count = df['neu'].sum().astype(int)

# Create a summary of the sentiment counts
sentiment_counts = {
    'positive': pos_count,
    'negative': neg_count,
    'neutral': neutral_count
}

# Print the sentiment counts
print(sentiment_counts)
# Out:
# {'positive': np.int64(183), 'negative': np.int64(22), 'neutral': np.int64(293)}

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# File path to the data
file_path = r'C:/Users/SOLOMON/Desktop/Python/Flipkart analyzed data.csv'

# Read the CSV file
df = pd.read_csv(file_path)

# Summing the sentiment counts
pos_count = df['pos'].sum().astype(int)
neg_count = df['neg'].sum().astype(int)
neutral_count = df['neu'].sum().astype(int)

# Data for visualization
labels = ['Positive', 'Negative', 'Neutral']
counts = [pos_count, neg_count, neutral_count]

# Convert data to DataFrame to use hue with Seaborn
sentiment_data = pd.DataFrame({'Sentiment': labels, 'Counts': counts})

# Creating the bar chart with hue and setting legend=False
sns.barplot(x='Sentiment', y='Counts', data=sentiment_data, hue='Sentiment', 
            palette=['green', 'red', 'gray'], legend=False)

plt.title('Sentiment Distribution Across All Comments')
plt.xlabel('Sentiment')
plt.ylabel('Number of Comments')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# File path to the data
file_path = r'C:/Users/SOLOMON/Desktop/Python/Flipkart analyzed data.csv'

# Read the CSV file
df = pd.read_csv(file_path)

# Summing the sentiment counts
pos_count = df['pos'].sum().astype(int)
neg_count = df['neg'].sum().astype(int)
neutral_count = df['neu'].sum().astype(int)

# Data for the pie chart
labels = ['Positive', 'Negative', 'Neutral']
sizes = [pos_count, neg_count, neutral_count]
colors = ['green', 'red', 'gray']

# Pie chart for sentiment distribution
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90, colors=colors)
plt.title('Sentiment Distribution Across All Comments')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
import pandas as pd

# File path to the data
file_path = r'C:/Users/SOLOMON/Desktop/Python/Flipkart analyzed data.csv'

# Read the CSV file
df = pd.read_csv(file_path)

# Summing the sentiment counts
pos_count = df['pos'].sum().astype(int)
neg_count = df['neg'].sum().astype(int)
neutral_count = df['neu'].sum().astype(int)

# Total number of comments
total_comments = 499  # You mentioned the total number of comments is 499

# Calculate the percentage distribution
sentiment_counts = {
    'positive': pos_count,
    'negative': neg_count,
    'neutral': neutral_count
}

sentiment_percentages = {k: (v / total_comments) * 100 for k, v in sentiment_counts.items()}

# Print the percentage distribution
print("Percentage Distribution:")
for sentiment, percentage in sentiment_percentages.items():
    print(f"{sentiment.capitalize()}: {percentage:.2f}%")
# Out:
# Percentage Distribution:
# Positive: 36.67%
# Negative: 4.41%
# Neutral: 58.72%
